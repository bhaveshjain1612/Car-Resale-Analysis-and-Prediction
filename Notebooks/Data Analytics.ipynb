# %% [markdown]
# # Data Analytics

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# The neccessary libraries for this notebook are imported along with the project library <br>
# Libraries used:
# - Pandas & Numpy : Data Handling
# - Seaborn & Matplotlib :

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

project_token = 'p-3f704f3cdf69a8a61cd7aa18710a153652a855a1'

from project_lib import Project
project = Project( project_access_token=project_token)
pc = project.project_context

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')
sns.set_palette('rainbow')

# %% [markdown]
# ## Importing Data

# %%
# The code was removed by Watson Studio for sharing.

# %%
data  = pd.read_csv(body)

# %%
data.head()
# Out:
#    selling_price (in lakhs)   age seller_type  km_driven (in thousands)  \
# 0                      1.20   9.0  Individual                     120.0
# 1                      5.50   5.0  Individual                      20.0
# 2                      2.15  11.0  Individual                      60.0
# 3                      2.26   9.0  Individual                      37.0
# 4                      5.70   6.0      Dealer                      30.0
#
#     owner_type fuel_type transmission_type  mileage  engine_size (in cc)  \
# 0  First Owner    Petrol            Manual    19.70                  796
# 1  First Owner    Petrol            Manual    18.90                 1197
# 2  First Owner    Petrol            Manual    17.00                 1197
# 3  First Owner    Petrol            Manual    20.92                  998
# 4  First Owner    Diesel            Manual    22.77                 1498
#
#    max_power (in bhp)  seats    maker     model  \
# 0               46.30      5   MARUTI      ALTO
# 1               82.00      5  HYUNDAI     GRAND
# 2               80.00      5  HYUNDAI       I20
# 3               67.10      5   MARUTI      ALTO
# 4               98.59      5     FORD  ECOSPORT
#
#                             variant
# 0                               STD
# 1                          I10 ASTA
# 2                              ASTA
# 3                 K10 2010-2014 VXI
# 4  2015-2021 1.5 TDCI TITANIUM BSIV

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=data['selling_price (in lakhs)'],bins=70,kde=True)
# Out:
# <AxesSubplot:xlabel='selling_price (in lakhs)', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=data['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
data['km_driven (in thousands)'].describe()
# Out:
# count    19631.000000
# mean        57.872333
# std         50.511827
# min          0.100000
# 25%         31.000000
# 50%         51.479000
# 75%         73.095500
# max       3800.000000
# Name: km_driven (in thousands), dtype: float64

# %% [markdown]
# ## Data Visualisation
